# %%
import tweepy
from tweepy import OAuthHandler

# %%
from tweepy import Stream
from tweepy.streaming import StreamListener
import socket
import json

# %%
consumer_key = '####'
consumer_secret = '####'
access_token = '#-#'
access_secret = '##'

# %%
class tweetsListener(StreamListener):
    def _init_(self,csocket):
        self.client_socket = csocket
    def on_data(self,data):
        try:
            msg = json.loads(data)
            print(msg['created_at'])
            print(msg['user']['name'])
            print(msg['user']['location'])
            print(msg['text'].encode('utf-8'))
            self.client_socket.send(msg['text'].encode('utf-8'))
            return True
        except BaseException as e:
            print("Error on data:%s" %str(e))
        return True
    def on_error(self,status):
        print(status)
        return True

# %%
def sendData(c_socket):
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_secret)
    twitter_stream = Stream(auth,tweetsListener(c_socket))
    twitter_stream.filter(track=['trump'])

# %%
s = socket.socket()

# %%
host = "172.31.38.183"
port = 1233

# %%
s.bind((host,port))
print("listening on the port %s" % str(port))
# Out:
# listening on the port 1233

# %%
s.listen(5)

# %%
c, addr = s.accept()

# %%
print("Received Request from :" +str( addr ))
# Out:
# Received Request from :('172.31.38.183', 38511)

# %%
sendData(c)
# Out:
# Wed Sep 27 20:07:54 +0000 2017
# Aoshins
# Florida
# RT @chrislhayes: Big headline today is Donald Trump is going to try to cut his own taxes by a huge amount.
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# denise
# Jalisco, México
# RT @jaboukie: fuck trump fuck nationalism fuck nazis fuck the police fuck the prison industrial complex fuck capitalism fuck clas…
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# staff 9 goat
# michigan
# @lasberry @Vladzhammer @dragon59 @alfredlionhart @HolyHeadshot No I was referring to trump and the NFL in a pissing match not people
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# kandi🌻
# None
# RT @curlyfry09: THIS is the reason people are kneeling. It's deeper than our dislike for trump. Its deeper than football.. ‼️ https://t.co/…
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# Horty Rexach
# Florida, USA
# RT @Impeach_D_Trump: Trump's #TaxReform Plan will FAIL as well...
#
# Why?
#
# Because The Man Promoting, Trump, it Is an Ignorant Failure himsel…
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# Meenab
# None
# RT @ALT_uscis: Trump: "African American employment is lowest since the millennia. Really a great thing"
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# Karl Stahnke
# Burbank, California
# @molly_knight Trump is consistent with Reagan and George W Bush.
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# Csa31
# None
# Why would anyone believe anything that @realDonaldTrump says?!?  The guy lies about 65% of the time. https://t.co/kiG8tYskMF
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# Amy C.
# Washington
# RT @SenGillibrand: Trump's tax plan helps large profitable corporations and millionaires, shortchanges lower income workers and the middle…
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# LCDR Obvious🚀🦑 🖖
# SSRN Seaview/FS1
# RT @jaketapper: .@mikeallen reports that @POTUS has been "physically mocking" @SenJohnMcCain, imitating how he did thumbs-down..1/
#
# https:…
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# Jordan Dickerson
# Hot Springs, AR
# RT @CahnEmily: Earlier today, Trump said they weren't removing a 100 yr old shipping rule that could help Puerto Rico bc the shipp…
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# Dat Action
# Views from a stage
# @DanielJWilliam4 @amdavis1967 @DerekUtleyCEO @RyanAFournier Will side with take a knee before anything else. Also l… https://t.co/mUsR0U4bmv
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# łukasz paweł
# None
# Donald Trump w Warszawie https://t.co/zrfprzU6Bt
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# The Upshot
# New York, NY
# RT @cliffordlevy: ‘Soon’
# ‘Very Soon’
# ‘Eventually’
# A very detailed list of things Trump said would happen https://t.co/2ThZQRmWqp https://t.…
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# MakeUSA_Great
# None
# RT @MissMaga2016: #TaxReform #Trump https://t.co/SwAK72FisN
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:07:54 +0000 2017
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:08:23 +0000 2017
# Rise&Resist
# Southern California
# RT @TheRickyDavila: He even lies about that. https://t.co/1310R632xL
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:08:23 +0000 2017
# Jody Murphy
# Richmond, VA
# RT @tomcolicchio: The Star Spangled Banner wasn't our national anthem until 1935 https://t.co/K8iyTGkywB
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Error on data:'created_at'
# Wed Sep 27 20:08:23 +0000 2017
# Gloria T
# None
# RT @therealcornett: LeBron James Calls Trump Voters ‘UNEDUCATED’ https://t.co/F8qYQ1lH0K via @truthfeednews
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:08:23 +0000 2017
# Insane Cheeto
# None
# RT @RogueSNRadvisor: Trump keeps saying it was his "plan all along" to have Roy Moore win. Says he "never actually wanted Strange."
#
# Sure t…
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:08:23 +0000 2017
# The Observer
# United States
# RT @TheRickyDavila: USNS Comfort is still not headed to Puerto Rico, yet trump is at a rally to talk about Tax Reform. Oh my God.
# https://t…
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:08:23 +0000 2017
# Amanda O.
# None
# When you were there to hear this in person 🙌🏻🙌🏻🙌🏻🙌🏻 #INBOUND2017 https://t.co/6Ix1FxXCGv
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:08:23 +0000 2017
# _
# Portland, OR
# RT @nycsouthpaw: Ah yes, the American dream of inheriting an undiminished fortune from your lordly mother and father. https://t.co/0Rcn2V71…
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# Wed Sep 27 20:08:23 +0000 2017
# jhijo
# Occitanie - FRANCE
# RT @bernardpivot1: En portant ses messages de 140 à 280 signes, Twitter permet à Trump de doubler la longueur de ses âneries et de ses mena…
# Error on data:'tweetsListener' object has no attribute 'client_socket'
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-12-9f2f6f948e99> in <module>()
# ----> 1 sendData(c)
#
# <ipython-input-5-e2c14e81ec3a> in sendData(c_socket)
#       3     auth.set_access_token(access_token, access_secret)
#       4     twitter_stream = Stream(auth,tweetsListener(c_socket))
# ----> 5     twitter_stream.filter(track=['trump'])
#
# /usr/local/anaconda/lib/python2.7/site-packages/tweepy/streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/anaconda/lib/python2.7/site-packages/tweepy/streaming.pyc in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# /usr/local/anaconda/lib/python2.7/site-packages/tweepy/streaming.pyc in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# /usr/local/anaconda/lib/python2.7/site-packages/tweepy/streaming.pyc in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# /usr/local/anaconda/lib/python2.7/site-packages/tweepy/streaming.pyc in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# /usr/local/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/response.pyc in read(self, amt, decode_content, cache_content)
#     378             else:
#     379                 cache_content = False
# --> 380                 data = self._fp.read(amt)
#     381                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     382                     # Close the connection when no data is returned
#
# /usr/local/anaconda/lib/python2.7/httplib.pyc in read(self, amt)
#     571
#     572         if self.chunked:
# --> 573             return self._read_chunked(amt)
#     574
#     575         if amt is None:
#
# /usr/local/anaconda/lib/python2.7/httplib.pyc in _read_chunked(self, amt)
#     613         while True:
#     614             if chunk_left is None:
# --> 615                 line = self.fp.readline(_MAXLINE + 1)
#     616                 if len(line) > _MAXLINE:
#     617                     raise LineTooLong("chunk size")
#
# /usr/local/anaconda/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /usr/local/anaconda/lib/python2.7/site-packages/requests/packages/urllib3/contrib/pyopenssl.pyc in recv(self, *args, **kwargs)
#     244         except OpenSSL.SSL.WantReadError:
#     245             rd, wd, ed = select.select(
# --> 246                 [self.socket], [], [], self.socket.gettimeout())
#     247             if not rd:
#     248                 raise timeout('The read operation timed out')
#
# KeyboardInterrupt:
