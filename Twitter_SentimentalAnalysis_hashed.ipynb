# %%
import time
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import json
from textblob import TextBlob
import matplotlib.pyplot as plt
import re

# %%
def calctime(a):
    return time.time()-a

# %%
positive=0
negative=0
compound=0

count=0
initime=time.time()
plt.ion()

# %%
atoken = '#-#'
asecret = '#'
ckey = '#'
csecret = '#'

# %%
class listener(StreamListener):
    
    def on_data(self,data):
        global initime
        t=int(calctime(initime))
        all_data=json.loads(data)
        tweet=all_data["text"].encode("utf-8")
        #username=all_data["user"]["screen_name"]
        tweet=" ".join(re.findall("[a-zA-Z]+", tweet))
        blob=TextBlob(tweet.strip())

        global positive
        global negative     
        global compound  
        global count
        
        count=count+1
        senti=0
        for sen in blob.sentences:
            senti=senti+sen.sentiment.polarity
            if sen.sentiment.polarity >= 0:
                positive=positive+sen.sentiment.polarity   
            else:
                negative=negative+sen.sentiment.polarity  
        compound=compound+senti        
        print count
        print tweet.strip()
        print senti
        print t
        print str(positive) + ' ' + str(negative) + ' ' + str(compound) 
        
    
        plt.axis([ 0, 70, -20,20])
        plt.xlabel('Time')
        plt.ylabel('Sentiment')
        plt.plot([t],[positive],'go',[t] ,[negative],'ro',[t],[compound],'bo')
        plt.show()
        plt.pause(0.0001)
        if count==200:
            return False
        else:
            return True
        
    def on_error(self,status):
        print status

# %%
auth=OAuthHandler(ckey,csecret)
auth.set_access_token(atoken,asecret)

# %%
twitterStream=  Stream(auth, listener(count))
twitterStream.filter(track=["Trump"])
# Out:
# 1
# RT Trumptbird Puerto Rico s only representative says the media coverage is unfair to our POTUS Gonzalez says President Trump ha
# -0.25
# 5
# 0 -0.25 -0.25
# 2
# oh fuck you trump you evil piece of shit https t co SHTAeCxZpv
# -0.533333333333
# 5
# 0 -0.783333333333 -0.783333333333
# 3
# RT WhiteHouse President Trump and the First Lady lead a moment of silence to honor those lost in the tragedy in Las Vegas https t co I
# 0.25
# 6
# 0.25 -0.783333333333 -0.533333333333
# 4
# Stop KrisKobach votersuppression https t co pVaNz VT
# 0.0
# 6
# 0.25 -0.783333333333 -0.533333333333
# 5
# leonbergers The only people who want trump are his trumpets who voted for him I don t think Russia wants him now https t co hulE fYPN
# 0.1
# 6
# 0.35 -0.783333333333 -0.433333333333
# 6
# RT JackPosobiec He wasn t President during San Bernadino or Orlando How much does BBC pay you https t co d qlufhyd
# 0.2
# 6
# 0.55 -0.783333333333 -0.233333333333
# 7
# Trump calls Las Vegas shooting an act of pure evil https t co sjchEmdnCZ
# -0.392857142857
# 6
# 0.55 -1.17619047619 -0.62619047619
# 8
# RT Freeyourmindkid Why didnt Trump call StephenPaddock a son of a bitch
# 0.0
# 6
# 0.55 -1.17619047619 -0.62619047619
# 9
# RT IsraelNewsLinks CNN Reporter Country Music Fans at Las Vegas Concert Were Likely Trump Supporters https t co s ofOWD qR via
# 0.0
# 7
# 0.55 -1.17619047619 -0.62619047619
# 10
# RT SteveBannen I noticed that racist CNN is largely ignoring the Puerto Rico governor who has been praising Trump is it because the gov
# -0.1
# 13
# 3.94970238095 -2.72619047619 1.22351190476
# 45
# RT chuckwoolery FBI is Awesome Figured out the shooter in Vegas was not linked to ISIS in hours Can t say Trump was not linked to R
# 1.0
# 13
# 4.94970238095 -2.72619047619 2.22351190476
# 46
# Bet k realDonaldTrump is going to pull up to the Trump Hotel on the strip in Vegas to endorse his hotel now
# 0.0
# 13
# 4.94970238095 -2.72619047619 2.22351190476
# 47
# RT ericswerdlin ZevShalev traciemac Bmore Bingo Trump narrative of pressing Xi is just more disinformation DJU is Putin s guy
# 0.5
# 13
# 5.44970238095 -2.72619047619 2.72351190476
# 48
# RT a b berurier Rajoy Trump Netanyahu el mundo en manos de locos criminales Y a m por qu no me incluyen en ese grupo eh Mac
# 0.0
# 14
# 5.44970238095 -2.72619047619 2.72351190476
# 49
# Can t make this stuff up https t co Hewsq ZTRv
# 0.0
# 14
# 5.44970238095 -2.72619047619 2.72351190476
# 50
# RT FIRE THE FOOL Any words that realDonaldTrump says today about the shooting are empty and false He reversed a bill to ban gun pu
# -0.25
# 14
# 5.44970238095 -2.97619047619 2.47351190476
# 51
# RT OhEmmeG yes bitch the fuck https t co PuO Bzg f
# -0.4
# 14
# 5.44970238095 -3.37619047619 2.07351190476
# 52
# DHS memo urged a cheery narrative on Puerto Rico while Trump attacked San Juan Mayor https t co evfmToJp i via PoliticsInsider
# 0.7
# 14
# 6.14970238095 -3.37619047619 2.77351190476
# 53
# RT cricaspp O pa s do sonho o lugar que meus filhos possam andar sem medo Fez campanha pro Freixo e vai pra terra do Trump
# 0.0
# 14
# 6.14970238095 -3.37619047619 2.77351190476
# 54
# Perfect NFL Running Back Wears Everybody vs Trump T Shirt with His Ass Hanging Out https t co Oi iCO jfk
# 0.5
# 15
# 6.64970238095 -3.37619047619 3.27351190476
# 55
# RT RealJack The fact that people are celebrating this attack because Trump supporters go to country concerts is incredibly disturbing
# -0.5
# 15
# 6.64970238095 -3.87619047619 2.77351190476
# 56
# RT TheTweetOfGod Bingo https t co ChMTSokTu
# 0.0
# 15
# 6.64970238095 -3.87619047619 2.77351190476
# 57
# RT Alyssa Milano Trump Signs Bill Revoking Obama Era Gun Checks for People With Mental Illnesses https t co xfK E Uc
# -0.1
# 15
# 6.64970238095 -3.97619047619 2.67351190476
# 58
# thepileus KrustyAllslopp Like Trump describing Charlottesville
# 0.0
# 15
# 6.64970238095 -3.97619047619 2.67351190476
# 59
# RT mskristinawong Hey Trump Is StephenPaddock a son of a bitch nasty or a terrorist Or nah
# -1.0
# 16
# 6.64970238095 -4.97619047619 1.67351190476
# 60
# Det er n sten kun fantasien der s tter gr nser for hvad han mon vil dedikere til ofrene i Las Vegas https t co TX f kU lr
# 0.0
# 16
# 6.64970238095 -4.97619047619 1.67351190476
# 61
# aliciapleure Donc oui stricto sensu c est illegal mais un tel deploiement de force c est juste n importe quoi Raj https t co w l escgpc
# -0.5
# 16
# 6.64970238095 -5.47619047619 1.17351190476
# 62
# RT lindamathieu bbusa They are Islam loyalist They don t want Trump a outsider to prove how corrupt the wa elite are TRUMP works
# -0.5
# 16
# 6.64970238095 -5.97619047619 0.673511904762
# 63
# bar set embarrassing low Trump He s only semi decent if he reads verbatim No press conferences because no knowl https t co lTEzg yVO
# 0.0555555555556
# 16
# 6.70525793651 -5.97619047619 0.729067460317
# 64
# realDonaldTrump Trump did create the hate it s inside of each individual
# -0.4
# 16
# 6.70525793651 -6.37619047619 0.329067460317
# 65
# Sean Hannity s Trump Interview Canceled in Wake of Las Vegas Shooting https t co YTyj DSwcN https t co mqJtl cHlG
# 0.0
# 17
# 6.70525793651 -6.37619047619 0.329067460317
# 66
# RT GeorgeTakei Not The Onion https t co PKmqGkLX Q
# 0.0
# 17
# 6.70525793651 -6.37619047619 0.329067460317
# 67
# RT ResistFromDay Jason Aldean Heartbroken Over Horrific Las Vegas Mass Shooting MAGA Trump https t co hojms hEX
# -1.0
# 17
# 6.70525793651 -7.37619047619 -0.670932539683
# 68
# RT wemustceasefire From hurricanes to shootings all Liberals call for is the death of Trump supporters This is why we have shootin
# 0.0
# 17
# 6.70525793651 -7.37619047619 -0.670932539683
# 69
# Article from Nov Trum amp Authoritarian Propaganda https t co uRG cHVDhp
# -0.1
# 17
# 6.70525793651 -7.47619047619 -0.770932539683
# 70
# RT Alyssa Milano Trump Signs Bill Revoking Obama Era Gun Checks for People With Mental Illnesses https t co xfK E Uc
# -0.1
# 18
# 6.70525793651 -7.57619047619 -0.870932539683
# 71
# Las Vegas tragedy is being exploited to bash realDonaldTrump Pod with YardleyShooting amp JackPosobiec https t co GHRy q KE
# 0.0
# 18
# 6.70525793651 -7.57619047619 -0.870932539683
# 72
# RT ahmedtwinkie RT FOR GOODLUCK https t co a IGwrYerx
# 0.0
# 18
# 6.70525793651 -7.57619047619 -0.870932539683
# 73
# RT harikondabolu REMINDER FOR DAY OF TRUMP PRESIDENCY THIS IS NOT NORMAL AND NORMAL WASN T THAT GREAT EITHER
# 0.291666666667
# 18
# 6.99692460317 -7.57619047619 -0.579265873016
# 74
# teilt HotpageNews TRUMP REMARKS HAVE no mention of assault weapons or gun violence Daily News hotpagenews https t co wNmyp oGJ
# 0.0
# 18
# 6.99692460317 -7.57619047619 -0.579265873016
# 75
# RT InkMyThoughts Nothing trump says is sincere Keep yo fuckin condolences bruh
# 0.5
# 18
# 7.49692460317 -7.57619047619 -0.0792658730159
# 76
# RT OhEmmeG yes bitch the fuck https t co PuO Bzg f
# -0.4
# 19
# 7.49692460317 -7.97619047619 -0.479265873016
# 77
# RT DaShanneStokes Trump incites violence and bragged that he could shoot someone and not lose voters Who is he to lecture America ab
# 0.0
# 19
# 7.49692460317 -7.97619047619 -0.479265873016
# 78
# RIPHef President Trump leads a moment of silence for the victims of the Las Vegas massacre https t co rZJysGIUF
# 0.0
# 19
# RT The Trump Train CNN the company that falsely claims Trump is racist is being sued by black employees for discrimination Not su
# -0.283333333333
# 25
# 9.54692460317 -10.5928571429 -1.04593253968
# 113
# RT MFAThai Hon Donald Trump President of the US and the First Lady welcomed Gen Prayut Chan o cha PM of Thailand and spouse
# 0.25
# 25
# 9.79692460317 -10.5928571429 -0.795932539683
# 114
# RT rivatez In Las Vegas watching the huge golden Trump hotel stand over a deserted strip covered in the blood of the people Poignant
# 0.233333333333
# 25
# 10.0302579365 -10.5928571429 -0.562599206349
# 115
# RT SocialPowerOne Pat Robertson Blames Vegas Shooting On Disrespect For Trump The National Anthem And God https t co AIRq xQb
# 0.0
# 26
# 10.0302579365 -10.5928571429 -0.562599206349
# 116
# Calvegas Harryslaststand Trump wants corporations too make billions with healthcare and increase shareholder value of the stockmarket
# 0.2
# 26
# 10.2302579365 -10.5928571429 -0.362599206349
# 117
# RT MichaelSkolnik Trump is speaking from a teleprompter Nothing from his heart Amazing to see a man who has no emotional connection to
# 0.3
# 26
# 10.5302579365 -10.5928571429 -0.0625992063492
# 118
# Shows how Trumpies team up with Da esh to oppose Truth Justice and the American Way Where s Superman when we ne https t co yh s hx Gd
# 0.0
# 26
# 10.5302579365 -10.5928571429 -0.0625992063492
# 119
# RT RodStryker Footage of Stephen Paddock at Anti Trump Reno Protest Aug MSM fake news hate filled Liberals are greatest thr
# 0.025
# 26
# 10.5552579365 -10.5928571429 -0.0375992063492
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-17-7b48ade4895d> in <module>()
#       1 twitterStream=  Stream(auth, listener(count))
# ----> 2 twitterStream.filter(track=["Trump"])
#
# /usr/local/anaconda/lib/python2.7/site-packages/tweepy/streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /usr/local/anaconda/lib/python2.7/site-packages/tweepy/streaming.pyc in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# /usr/local/anaconda/lib/python2.7/site-packages/tweepy/streaming.pyc in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# /usr/local/anaconda/lib/python2.7/site-packages/tweepy/streaming.pyc in _read_loop(self, resp)
#     322             next_status_obj = buf.read_len(length)
#     323             if self.running:
# --> 324                 self._data(next_status_obj)
#     325
#     326             # # Note: keep-alive newlines might be inserted before each length value.
#
# /usr/local/anaconda/lib/python2.7/site-packages/tweepy/streaming.pyc in _data(self, data)
#     295
#     296     def _data(self, data):
# --> 297         if self.listener.on_data(data) is False:
#     298             self.running = False
#     299
#
# <ipython-input-15-08b925d24ace> in on_data(self, data)
#      31
#      32
# ---> 33         plt.axis([ 0, 70, -20,20])
#      34         plt.xlabel('Time')
#      35         plt.ylabel('Sentiment')
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in axis(*v, **kwargs)
#    1535            For setting the x- and y-limits individually.
#    1536     """
# -> 1537     return gca().axis(*v, **kwargs)
#    1538
#    1539
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in gca(**kwargs)
#     948     matplotlib.figure.Figure.gca : The figure's gca method.
#     949     """
# --> 950     return gcf().gca(**kwargs)
#     951
#     952 # More ways of creating axes:
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in gca(self, **kwargs)
#    1366
#    1367         # no axes found, so create one which spans the figure
# -> 1368         return self.add_subplot(1, 1, 1, **kwargs)
#    1369
#    1370     def sca(self, a):
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#    1018                     self._axstack.remove(ax)
#    1019
# -> 1020             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1021
#    1022         self._axstack.add(key, a)
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axes/_subplots.pyc in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, axisbg, **kwargs)
#     527
#     528         # this call may differ for non-sep axes, e.g., polar
# --> 529         self._init_axis()
#     530         if axisbg is not None and facecolor is not None:
#     531             raise TypeError('Both axisbg and facecolor are not None. '
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axes/_base.pyc in _init_axis(self)
#     620     def _init_axis(self):
#     621         "move this out of __init__ because non-separable axes don't use it"
# --> 622         self.xaxis = maxis.XAxis(self)
#     623         self.spines['bottom'].register_axis(self.xaxis)
#     624         self.spines['top'].register_axis(self.xaxis)
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, pickradius)
#     674         self._minor_tick_kw = dict()
#     675
# --> 676         self.cla()
#     677         self._set_scale('linear')
#     678
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in cla(self)
#     758         self._set_artist_props(self.label)
#     759
# --> 760         self.reset_ticks()
#     761
#     762         self.converter = None
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in reset_ticks(self)
#     772         cbook.popall(self.minorTicks)
#     773
# --> 774         self.majorTicks.extend([self._get_tick(major=True)])
#     775         self.minorTicks.extend([self._get_tick(major=False)])
#     776         self._lastNumMajorTicks = 1
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick(self, major)
#    1727         else:
#    1728             tick_kw = self._minor_tick_kw
# -> 1729         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1730
#    1731     def _get_label(self):
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/axis.pyc in _get_tick1line(self)
#     418                           linestyle='None', marker=self._tickmarkers[0],
#     419                           markersize=self._size,
# --> 420                           markeredgewidth=self._width, zorder=self._zorder)
#     421         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     422         self._set_artist_props(l)
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     423         self.set_markeredgewidth(markeredgewidth)
#     424
# --> 425         self.set_fillstyle(fillstyle)
#     426
#     427         self.verticalOffset = None
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/lines.pyc in set_fillstyle(self, fs)
#     553         ACCEPTS: ['full' | 'left' | 'right' | 'bottom' | 'top' | 'none']
#     554         """
# --> 555         self._marker.set_fillstyle(fs)
#     556         self.stale = True
#     557
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/markers.pyc in set_fillstyle(self, fillstyle)
#     235                              % ' '.join(self.fillstyles))
#     236         self._fillstyle = fillstyle
# --> 237         self._recache()
#     238
#     239     def get_joinstyle(self):
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/markers.pyc in _recache(self)
#     206         self._capstyle = 'butt'
#     207         self._filled = True
# --> 208         self._marker_function()
#     209
#     210     if six.PY3:
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/markers.pyc in _set_tickdown(self)
#     718
#     719     def _set_tickdown(self):
# --> 720         self._transform = Affine2D().scale(1.0, -1.0)
#     721         self._snap_threshold = 1.0
#     722         self._filled = False
#
# /usr/local/anaconda/lib/python2.7/site-packages/matplotlib/transforms.pyc in scale(self, sx, sy)
#    1985         scale_mtx = np.array(
#    1986             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]],
# -> 1987             np.float_)
#    1988         self._mtx = np.dot(scale_mtx, self._mtx)
#    1989         self.invalidate()
#
# KeyboardInterrupt:
